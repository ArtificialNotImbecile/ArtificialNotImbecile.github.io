# %%
from dahua_ipc import DahuaRpc

# %%
dh = DahuaRpc("172.16.115.203", "admin", "1234567a")
dh.login()
true = True
false = False

# %%
print(dh.request(method="magicBox.getSerialNo"))
# Out:
# {'result': True, 'params': {'sn': '5E0246CRAG5FE67'}, 'id': 3, 'session': '528b19e6423f52657362933'}

# %%
dh.request(method="configManager.getConfig", params={"name":"Encode"})
# Out:
# {'result': True,
#  'params': {'table': [{'MainFormat': [{'Audio': {'Bitrate': 64,
#        'Channels': [0],
#        'Compression': 'G.711A',
#        'Depth': 16,
#        'Frequency': 8000,
#        'Mode': 0,
#        'Pack': 'DHAV'},
#       'AudioEnable': True,
#       'Video': {'BitRate': 4096,
#        'FPS': 25,
#        'GOP': 50,
#        'Width': 1920,
#        'Height': 1080,
#        'Priority': 0,
#        'Quality': 4,
#        'QualityRange': 6,
#        'SVCTLayer': 1,
#        'Profile': 'Main',
#        'BitRateControl': 'CBR',
#        'Compression': 'H.264',
#        'CustomResolutionName': '1080P',
#        'Pack': 'DHAV'},
#       'VideoEnable': True},
#      {'Audio': {'Bitrate': 64,
#        'Channels': [0],
#        'Compression': 'G.711A',
#        'Depth': 16,
#        'Frequency': 8000,
#        'Mode': 0,
#        'Pack': 'DHAV'},
#       'AudioEnable': True,
#       'Video': {'BitRate': 4096,
#        'FPS': 25,
#        'GOP': 50,
# ...

# %% [markdown]
# # use chrome developer-Network tool to get the payload

# %%
payload = {
  "method": "encode.getConfigCaps",
  "params": {
    "channel": 0,
    "config": [
      {
        # Main format settings 
        "MainFormat": [
          {
            # Audio settings
            "Audio": {
              "Bitrate": 64, 
              "Channels": [0],
              "Compression": "G.711A",
              "Depth": 16,
              "Frequency": 8000,
              "Mode": 0,
              "Pack": "DHAV"
            },
            "AudioEnable": True,
            
            # Video settings
            "Video": {
              "BitRate": 4096,
              "FPS": 25,
              "GOP": 50, 
              "Width": 1920,
              "Height": 1080,
              "Priority": 0,
              "Quality": 4,
              "QualityRange": 6,
              "SVCTLayer": 1,
              "Profile": "Main",
              "BitRateControl": "CBR",
              "Compression": "H.264",
              "CustomResolutionName": "1080P",
              "Pack": "DHAV"
            },
            "VideoEnable": True
          },
          
          # Add other main format settings here
        ],
        
        # Extra format settings
        "ExtraFormat": [
          {
            # Audio settings 
            "Audio": {
              "Bitrate": 64,
              "Channels": [0],  
              "Compression": "G.711A",
              "Depth": 16,
              "Frequency": 8000,
              "Pack": "DHAV"
            },
            "AudioEnable": False,
            
            # Video settings
            "Video": {
              "BitRate": 512,
              "FPS": 25,
              "GOP": 50,
              "Width": 704,
              "Height": 576,  
              "Priority": 0,
              "Quality": 4,
              "QualityRange": 6,
              "SVCTLayer": 1,
              "Profile": "Main",
              "BitRateControl": "CBR",
              "Compression": "H.264",
              "CustomResolutionName": "D1",
              "Pack": "DHAV"
            },
            "VideoEnable": True 
          },
          
          # Add other extra format settings here
        ],
        
        # Snapshot format settings
        "SnapFormat": [
          {
            # Audio settings
            "Audio": {
              "Bitrate": 64,
              "Compression": "G.711A",
              "Depth": 16,
              "Frequency": 8000,
              "Pack": "DHAV"
            },
            "AudioEnable": False,
            
            # Video settings  
            "Video": {
              "BitRate": 5120,
              "FPS": 1,
              "GOP": 2,
              "Width": 1920,
              "Height": 1080,
              "Priority": 0,
              "Quality": 5,
              "QualityRange": 6,
              "SVCTLayer": 1,
              "Profile": "Baseline",
              "BitRateControl": "VBR",
              "Compression": "MJPG",
              "CustomResolutionName": "1080P",
              "Pack": "DHAV"
            },
            "VideoEnable": True
          },
          
          # Add other snapshot format settings here
        ]
      }
    ],
    "stream": "All" 
  },
  "id": 437,
  "session": "528b1974949c32538162627"
}

# %%
result = dh.request(method=payload["method"], params=payload["params"])

# %%
payload = {
  "method": "system.multicall",
  "params": [
    {
      "method": "configManager.setConfig",
      "params": {
        "name": "Encode",
        "table": [
          {
            "MainFormat": [
              {
                "Audio": {
                  "Bitrate": 64,
                  "Channels": [0],
                  "Compression": "G.711A", 
                  "Depth": 16,
                  "Frequency": 8000,
                  "Mode": 0,
                  "Pack": "DHAV"
                },
                "AudioEnable": True,
                "Video": {
                  "BitRate": 6144,
                  "FPS": 25,
                  "GOP": 50, 
                  "Width": 1920,
                  "Height": 1080,
                  "Priority": 0,
                  "Quality": 4,
                  "QualityRange": 6,
                  "SVCTLayer": 1,
                  "Profile": "Main",
                  "BitRateControl": "CBR",
                  "Compression": "H.264",
                  "CustomResolutionName": "1080P",
                  "Pack": "DHAV"
                },
                "VideoEnable": True
              }  
            ]
          },
          {
            "ExtraFormat": [
              {
                "Audio": {
                  "Bitrate": 64,
                  "Channels": [0],
                  "Compression": "G.711A",
                  "Depth": 16,
                  "Frequency": 8000,
                  "Pack": "DHAV"
                },
                "AudioEnable": False,
                "Video": {
                  "BitRate": 512,
                  "FPS": 25,
                  "GOP": 50,
                  "Width": 704,
                  "Height": 576,
                  "Priority": 0,
                  "Quality": 4,
                  "QualityRange": 6,
                  "SVCTLayer": 1,
                  "Profile": "Main",
                  "BitRateControl": "CBR", 
                  "Compression": "H.264",
                  "CustomResolutionName": "D1",
                  "Pack": "DHAV"
                },
                "VideoEnable": True
              }
            ]  
          },
          {
            "SnapFormat": [
              {
                "Audio": {
                  "Bitrate": 64,
                  "Compression": "G.711A",
                  "Depth": 16, 
                  "Frequency": 8000,
                  "Pack": "DHAV"
                },
                "AudioEnable": False,
                "Video": {
                  "BitRate": 5120,
                  "FPS": 1,
                  "GOP": 2,
                  "Width": 1920, 
                  "Height": 1080,
                  "Priority": 0,
                  "Quality": 5,
                  "QualityRange": 6,
                  "SVCTLayer": 1, 
                  "Profile": "Baseline",
                  "BitRateControl": "VBR",
                  "Compression": "MJPG",
                  "CustomResolutionName": "1080P",
                  "Pack": "DHAV"
                },
                "VideoEnable": True
              }
            ]
          }
        ],
        "options": []
      },
      "id": 282,
      "session": "528b198e4ed072565139719"
    },
    {
      "method": "configManager.setConfig",
      "params": {
        "name": "VideoWaterMark",
        "table": [
          {
            "Enable": True,
            "Key": "1",
            "String": "DigitalCCTV"
          }
        ],
        "options": []  
      },
      "id": 283,
      "session": "528b198e4ed072565139719"
    },
    {
      "method": "configManager.setConfig",
      "params": {
        "name": "SmartEncode",
        "table": [
          {
            "Enable": False
          }
        ],
        "options": []
      },
      "id": 284,
      "session": "528b198e4ed072565139719"
    }
  ],
  "id": 285,
  "session": "528b198e4ed072565139719"
}

# %%
payload['params'][0]
# Out:
# {'method': 'configManager.setConfig',
#  'params': {'name': 'Encode',
#   'table': [{'MainFormat': [{'Audio': {'Bitrate': 64,
#        'Channels': [0],
#        'Compression': 'G.711A',
#        'Depth': 16,
#        'Frequency': 8000,
#        'Mode': 0,
#        'Pack': 'DHAV'},
#       'AudioEnable': True,
#       'Video': {'BitRate': 6144,
#        'FPS': 25,
#        'GOP': 50,
#        'Width': 1920,
#        'Height': 1080,
#        'Priority': 0,
#        'Quality': 4,
#        'QualityRange': 6,
#        'SVCTLayer': 1,
#        'Profile': 'Main',
#        'BitRateControl': 'CBR',
#        'Compression': 'H.264',
#        'CustomResolutionName': '1080P',
#        'Pack': 'DHAV'},
#       'VideoEnable': True}]},
#    {'ExtraFormat': [{'Audio': {'Bitrate': 64,
#        'Channels': [0],
#        'Compression': 'G.711A',
#        'Depth': 16,
#        'Frequency': 8000,
#        'Pack': 'DHAV'},
#       'AudioEnable': False,
#       'Video': {'BitRate': 512,
#        'FPS': 25,
# ...

# %%
payload = {
    "method": "system.multicall",
    "params": [
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoColor",
                "table": [[
                    {"Brightness": 50, "ChromaSuppress": 50, "Contrast": 50, "Gamma": 50, "Hue": 50, "Saturation": 50, "Style": "Standard", "TimeSection": "1 00:00:00-24:00:00"}, 
                    {"Brightness": 50, "ChromaSuppress": 50, "Contrast": 50, "Gamma": 50, "Hue": 50, "Saturation": 50, "Style": "Standard", "TimeSection": "0 00:00:00-24:00:00"},  
                    {"Brightness": 50, "ChromaSuppress": 50, "Contrast": 50, "Gamma": 50, "Hue": 50, "Saturation": 50, "Style": "Standard", "TimeSection": "0 00:00:00-24:00:00"}
                ]], 
                "options": []
            },
            "id": 305,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoImageControl",
                "table": [{"Mirror": false, "Flip": false, "Freeze": false, "Rotate90": 0, "Stable": 0}],
                "options": []
            },
            "id": 306,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig", 
            "params": {
                "name": "VideoInSharpness",
                "table": [[
                    {"Level": 50, "Sharpness": 50, "Mode": 1},
                    {"Level": 50, "Sharpness": 50, "Mode": 1}, 
                    {"Level": 50, "Sharpness": 50, "Mode": 1}
                ]],
                "options": []
            },
            "id": 307,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoInExposure",
                "table": [[
                    {
                        "AntiFlicker": 0, 
                        "AutoGainMax": 2, 
                        "Backlight": 0, 
                        "BacklightRegion": [3096, 3096, 5096, 5096],
                        "Compensation": 50, 
                        "DoubleExposure": 0, 
                        "Gain": 1, 
                        "GainMax": 50, 
                        "GainMin": 0, 
                        "GlareInhibition": 0, 
                        "Iris": 50, 
                        "IrisAuto": true, 
                        "IrisMax": 50, 
                        "IrisMin": 0, 
                        "Mode": 0, 
                        "RecoveryTime": 900, 
                        "Rect": [0, 0, 0, 0], 
                        "SlowAutoExposure": 0, 
                        "SlowShutter": false, 
                        "SlowSpeed": 25, 
                        "Value1": 40, 
                        "Value2": 40, 
                        "WideDynamicRange": 0, 
                        "WideDynamicRangeMode": 0
                    }, 
                    {
                        "AntiFlicker": 0, 
                        "AutoGainMax": 2, 
                        "Backlight": 0, 
                        "BacklightRegion": [3096, 3096, 5096, 5096],
                        "Compensation": 50, 
                        "DoubleExposure": 0, 
                        "Gain": 1,  
                        "GainMax": 50, 
                        "GainMin": 0, 
                        "GlareInhibition": 0, 
                        "Iris": 50, 
                        "IrisAuto": true, 
                        "IrisMax": 50, 
                        "IrisMin": 0,  
                        "Mode": 0, 
                        "RecoveryTime": 900, 
                        "Rect": [0, 0, 0, 0], 
                        "SlowAutoExposure": 0, 
                        "SlowShutter": false, 
                        "SlowSpeed": 25, 
                        "Value1": 40, 
                        "Value2": 40, 
                        "WideDynamicRange": 0, 
                        "WideDynamicRangeMode": 0
                    },
                    {
                        "AntiFlicker": 0,  
                        "AutoGainMax": 2, 
                        "Backlight": 0, 
                        "BacklightRegion": [3096, 3096, 5096, 5096],
                        "Compensation": 50, 
                        "DoubleExposure": 0, 
                        "Gain": 1, 
                        "GainMax": 50, 
                        "GainMin": 0, 
                        "GlareInhibition": 0,  
                        "Iris": 50, 
                        "IrisAuto": true, 
                        "IrisMax": 50, 
                        "IrisMin": 0, 
                        "Mode": 0, 
                        "RecoveryTime": 900, 
                        "Rect": [0, 0, 0, 0],  
                        "SlowAutoExposure": 0, 
                        "SlowShutter": false, 
                        "SlowSpeed": 25, 
                        "Value1": 40, 
                        "Value2": 40, 
                        "WideDynamicRange": 0, 
                        "WideDynamicRangeMode": 0
                    }
                ]],
                "options": []
            },
            "id": 308,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoInDenoise",
                "table": [[
                    {
                        "2DEnable": true,
                        "2DLevel": 3, 
                        "3DAutoType": {"AutoLevel": 50},
                        "3DManulType": {"SnfLevel": 50, "TnfLevel": 0},
                        "3DType": "Auto",
                        "DenoiseAlgorithm1": {"SnfLevel": 50, "TnfLevel": 50, "Type": "Manual"}
                    },
                    {
                        "2DEnable": true, 
                        "2DLevel": 3,
                        "3DAutoType": {"AutoLevel": 50},  
                        "3DManulType": {"SnfLevel": 50, "TnfLevel": 0},
                        "3DType": "Auto",
                        "DenoiseAlgorithm1": {"SnfLevel": 50, "TnfLevel": 50, "Type": "Manual"}
                    },
                    {
                        "2DEnable": true,
                        "2DLevel": 3,
                        "3DAutoType": {"AutoLevel": 50},
                        "3DManulType": {"SnfLevel": 50, "TnfLevel": 0},  
                        "3DType": "Auto",
                        "DenoiseAlgorithm1": {"SnfLevel": 50, "TnfLevel": 50, "Type": "Manual"}
                    }
                ]],
                "options": []
            },
            "id": 309,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoInIRExposure",
                "table": [[
                    {"Enable": false},
                    {"Enable": false},
                    {"Enable": false}
                ]],
                "options": []
            },
            "id": 310,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoInBacklight",
                "table": [[
                    {
                        "BacklightMode": "Default",
                        "BacklightRegion": [3096, 3096, 5096, 5096],
                        "GlareInhibition": 50,
                        "Intensity": 50,
                        "IntensityMode": "Disable",
                        "Mode": "WideDynamic",
                        "WideDynamicRange": 50
                    },
                    {
                        "BacklightMode": "Default",
                        "BacklightRegion": [3096, 3096, 5096, 5096],  
                        "GlareInhibition": 50,
                        "Intensity": 50,
                        "IntensityMode": "Disable",
                        "Mode": "Off",
                        "WideDynamicRange": 50
                    },
                    {
                        "BacklightMode": "Default",
                        "BacklightRegion": [3096, 3096, 5096, 5096],
                        "GlareInhibition": 50,
                        "Intensity": 50,
                        "IntensityMode": "Disable",
                        "Mode": "Off",
                        "WideDynamicRange": 50
                    }
                ]],
                "options": []
            },
            "id": 311,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoInWhiteBalance",
                "table": [[
                    {
                        "ColorTemperatureLevel": 50,
                        "GainBlue": 22,
                        "GainGreen": 50, 
                        "GainRed": 35,
                        "ManualDatumRect": [3096, 3096, 5096, 5096],
                        "Mode": "Auto"
                    },
                    {
                        "ColorTemperatureLevel": 50,
                        "GainBlue": 22, 
                        "GainGreen": 50,
                        "GainRed": 35,  
                        "ManualDatumRect": [3096, 3096, 5096, 5096],
                        "Mode": "Auto"
                    },
                    {
                        "ColorTemperatureLevel": 50,
                        "GainBlue": 22,
                        "GainGreen": 50,
                        "GainRed": 35,
                        "ManualDatumRect": [3096, 3096, 5096, 5096],
                        "Mode": "Auto"
                    }
                ]],
                "options": []
            },
            "id": 312,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "VideoInDayNight",
                "table": [[
                    {"Delay": 6, "Mode": "Brightness", "Sensitivity": 2, "Type": "Mechanism"},
                    {"Delay": 6, "Mode": "Brightness", "Sensitivity": 2, "Type": "Mechanism"},
                    {"Delay": 6, "Mode": "Brightness", "Sensitivity": 2, "Type": "Mechanism"}
                ]],
                "options": []
            },
            "id": 313,
            "session": "528b1994bd5d82571883992"
        },
        {
            "method": "configManager.setConfig",
            "params": {
                "name": "Lighting",
                "table": [[
                    {
                        "Mode": "Auto",
                        "Sensitive": 3,
                        "Correction": 2,
                        "MiddleLight": [{"Angle": 50, "Light": 50}]
                    }
                ]],
                "options": []
            },
            "id": 314,
            "session": "528b1994bd5d82571883992"
        }
    ],
    "id": 315,
    "session": "528b1994bd5d82571883992"
}

# %%
idx = 6 # wdr
dh.request(method=payload['params'][idx]['method'], params=payload['params'][idx]['params'])
# Out:
# {'result': True, 'params': {}, 'id': 12, 'session': '528b1994bd5d82571883992'}

# %%
# set all
dh.request(method=payload['method'], params=payload['params'])
# Out:
# {'result': True,
#  'params': [{'result': True, 'id': 305, 'params': {}},
#   {'result': True, 'id': 306, 'params': {}},
#   {'result': True, 'id': 307, 'params': {}},
#   {'result': True, 'id': 308, 'params': {}},
#   {'result': True, 'id': 309, 'params': {}},
#   {'result': True, 'id': 310, 'params': {}},
#   {'result': True, 'id': 311, 'params': {}},
#   {'result': True, 'id': 312, 'params': {}},
#   {'result': True, 'id': 313, 'params': {}},
#   {'result': True, 'id': 314, 'params': {}}],
#  'id': 13,
#  'session': '528b1994bd5d82571883992'}

# %%
payload = {
	"method": "system.multicall",
	"params": [
		{
			"method": "configManager.setConfig",
			"params": {
				"name": "Encode",
				"table": [
					{
						"MainFormat": [
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Mode": 0,
									"Pack": "DHAV"
								},
								"AudioEnable": true,
								"Video": {
									"BitRate": 6143,
									"FPS": 25,
									"GOP": 50,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Mode": 0,
									"Pack": "DHAV"
								},
								"AudioEnable": true,
								"Video": {
									"BitRate": 4096,
									"FPS": 25,
									"GOP": 50,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Mode": 0,
									"Pack": "DHAV"
								},
								"AudioEnable": true,
								"Video": {
									"BitRate": 4096,
									"FPS": 25,
									"GOP": 50,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Mode": 0,
									"Pack": "DHAV"
								},
								"AudioEnable": true,
								"Video": {
									"BitRate": 4096,
									"FPS": 25,
									"GOP": 50,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							}
						],
						"ExtraFormat": [
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Pack": "DHAV"
								},
								"AudioEnable": false,
								"Video": {
									"BitRate": 512,
									"FPS": 25,
									"GOP": 50,
									"Width": 704,
									"Height": 576,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "D1",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Pack": "DHAV"
								},
								"AudioEnable": false,
								"Video": {
									"BitRate": 512,
									"FPS": 25,
									"GOP": 50,
									"Width": 704,
									"Height": 576,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "D1",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Channels": [
										0
									],
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Pack": "DHAV"
								},
								"AudioEnable": false,
								"Video": {
									"BitRate": 512,
									"FPS": 25,
									"GOP": 50,
									"Width": 704,
									"Height": 576,
									"Priority": 0,
									"Quality": 4,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Main",
									"BitRateControl": "CBR",
									"Compression": "H.264",
									"CustomResolutionName": "D1",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							}
						],
						"SnapFormat": [
							{
								"Audio": {
									"Bitrate": 64,
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Pack": "DHAV"
								},
								"AudioEnable": false,
								"Video": {
									"BitRate": 5120,
									"FPS": 1,
									"GOP": 2,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 5,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Baseline",
									"BitRateControl": "VBR",
									"Compression": "MJPG",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Pack": "DHAV"
								},
								"AudioEnable": false,
								"Video": {
									"BitRate": 5120,
									"FPS": 1,
									"GOP": 2,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 5,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Baseline",
									"BitRateControl": "VBR",
									"Compression": "MJPG",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							},
							{
								"Audio": {
									"Bitrate": 64,
									"Compression": "G.711A",
									"Depth": 16,
									"Frequency": 8000,
									"Pack": "DHAV"
								},
								"AudioEnable": false,
								"Video": {
									"BitRate": 5120,
									"FPS": 1,
									"GOP": 2,
									"Width": 1920,
									"Height": 1080,
									"Priority": 0,
									"Quality": 5,
									"QualityRange": 6,
									"SVCTLayer": 1,
									"Profile": "Baseline",
									"BitRateControl": "VBR",
									"Compression": "MJPG",
									"CustomResolutionName": "1080P",
									"Pack": "DHAV"
								},
								"VideoEnable": true
							}
						]
					}
				],
				"options": [

				]
			},
			"id": 330,
			"session": "528b19b4e61ed2605605357"
		},
		{
			"method": "configManager.setConfig",
			"params": {
				"name": "VideoWaterMark",
				"table": [
					{
						"Enable": true,
						"Key": "1",
						"String": "DigitalCCTV"
					}
				],
				"options": [

				]
			},
			"id": 331,
			"session": "528b19b4e61ed2605605357"
		},
		{
			"method": "configManager.setConfig",
			"params": {
				"name": "SmartEncode",
				"table": [
					{
						"Enable": false
					}
				],
				"options": [

				]
			},
			"id": 332,
			"session": "528b19b4e61ed2605605357"
		}
	],
	"id": 333,
	"session": "528b19b4e61ed2605605357"
}

# %%
dh.request(method=payload['method'], params=payload['params'])
# Out:
# {'result': True,
#  'params': [{'result': True, 'id': 330, 'params': {'options': None}},
#   {'result': True, 'id': 331, 'params': {'options': None}},
#   {'result': True, 'id': 332}],
#  'id': 3,
#  'session': '528b19ea8bf2b2661859115'}
